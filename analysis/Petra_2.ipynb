# %%
import pandas as pd

# Set options to show all columns
pd.set_option('display.max_columns', None)

# Upload csv file
data = r'C:\repos\immo-eliza-team6-analysis\analysis\PL_clean_data_no_outliers.csv' # Fill your path to file
df = pd.read_csv(data, sep = ',')


df.dtypes
# Out:
# id                      int64
# locality_name          object
# Postal_code             int64
# Price                   int64
# Subtype                object
# Number_of_bedrooms      int64
# Living_area             int64
# street                 object
# number                 object
# latitude              float64
# longitude             float64
# Open_fire               int64
# Swimming_Pool           int64
# hasTerrace              int64
# terraceSurface          int64
# gardenSurface           int64
# Kitchen_type           object
# Number_of_facades       int64
# State_of_building      object
# Furnished               int64
# epc                    object
# price_per_sqm         float64
# dtype: object

# %%
# transform dtypes 'object' to 'category'
int_columns = df.select_dtypes(include=['object'])

for col in int_columns.columns:
    df[col] = df[col].astype('category')

df['Postal_code']= df['Postal_code'].astype('string')

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5828 entries, 0 to 5827
# Data columns (total 22 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  5828 non-null   int64
#  1   locality_name       5828 non-null   category
#  2   Postal_code         5828 non-null   string
#  3   Price               5828 non-null   int64
#  4   Subtype             5828 non-null   category
#  5   Number_of_bedrooms  5828 non-null   int64
#  6   Living_area         5828 non-null   int64
#  7   street              5828 non-null   category
#  8   number              5807 non-null   category
#  9   latitude            5823 non-null   float64
#  10  longitude           5823 non-null   float64
#  11  Open_fire           5828 non-null   int64
#  12  Swimming_Pool       5828 non-null   int64
#  13  hasTerrace          5828 non-null   int64
#  14  terraceSurface      5828 non-null   int64
#  15  gardenSurface       5828 non-null   int64
#  16  Kitchen_type        3607 non-null   category
#  17  Number_of_facades   5828 non-null   int64
#  18  State_of_building   5273 non-null   category
#  19  Furnished           5828 non-null   int64
#  20  epc                 5557 non-null   category
#  21  price_per_sqm       5828 non-null   float64
# dtypes: category(7), float64(3), int64(11), string(1)
# memory usage: 966.0 KB

# %%
import seaborn as sns
import matplotlib.pylab as plt
plt.style.use('ggplot')

df.corr(method='pearson', min_periods=1, numeric_only=True)
# Out:
#                           id     Price  Number_of_bedrooms  Living_area  \
# id                  1.000000  0.030632           -0.018976    -0.030881
# Price               0.030632  1.000000            0.392019     0.599834
# Number_of_bedrooms -0.018976  0.392019            1.000000     0.559848
# Living_area        -0.030881  0.599834            0.559848     1.000000
# latitude            0.068490  0.214067            0.007498     0.075542
# longitude          -0.067578 -0.002843            0.000232    -0.034035
# Open_fire          -0.017012  0.143410            0.057932     0.145203
# Swimming_Pool       0.004612  0.158491            0.081291     0.110027
# hasTerrace          0.019968  0.112585            0.032936     0.042317
# terraceSurface     -0.013665  0.075005            0.045503     0.060081
# gardenSurface      -0.041021  0.148955            0.072813     0.122486
# Number_of_facades  -0.058743  0.178667            0.063404     0.121089
# Furnished           0.004838 -0.016458           -0.023323    -0.055074
# price_per_sqm       0.066014  0.580718           -0.087879    -0.251275
#
#                     latitude  longitude  Open_fire  Swimming_Pool  hasTerrace  \
# id                  0.068490  -0.067578  -0.017012       0.004612    0.019968
# Price               0.214067  -0.002843   0.143410       0.158491    0.112585
# Number_of_bedrooms  0.007498   0.000232   0.057932       0.081291    0.032936
# Living_area         0.075542  -0.034035   0.145203       0.110027    0.042317
# latitude            1.000000  -0.520111  -0.049153      -0.016701   -0.087048
# longitude          -0.520111   1.000000   0.068271       0.047966    0.101986
# Open_fire          -0.049153   0.068271   1.000000       0.091481    0.052848
# Swimming_Pool      -0.016701   0.047966   0.091481       1.000000    0.071459
# hasTerrace         -0.087048   0.101986   0.052848       0.071459    1.000000
# terraceSurface     -0.109245   0.141176   0.074322       0.078043    0.231906
# gardenSurface      -0.147544   0.146057   0.109714       0.114196    0.078274
# Number_of_facades  -0.135533   0.250472   0.130298       0.090978    0.108264
# Furnished          -0.041293   0.025329   0.003509      -0.003961    0.044873
# price_per_sqm       0.193398   0.017744   0.025555       0.068404    0.098283
#
#                     terraceSurface  gardenSurface  Number_of_facades  \
# id                       -0.013665      -0.041021          -0.058743
# Price                     0.075005       0.148955           0.178667
# Number_of_bedrooms        0.045503       0.072813           0.063404
# Living_area               0.060081       0.122486           0.121089
# latitude                 -0.109245      -0.147544          -0.135533
# longitude                 0.141176       0.146057           0.250472
# Open_fire                 0.074322       0.109714           0.130298
# Swimming_Pool             0.078043       0.114196           0.090978
# hasTerrace                0.231906       0.078274           0.108264
# terraceSurface            1.000000       0.175306           0.102653
# gardenSurface             0.175306       1.000000           0.197334
# Number_of_facades         0.102653       0.197334           1.000000
# Furnished                 0.024312       0.005251          -0.022387
# price_per_sqm             0.028587       0.046632           0.083105
#
#                     Furnished  price_per_sqm
# id                   0.004838       0.066014
# Price               -0.016458       0.580718
# Number_of_bedrooms  -0.023323      -0.087879
# Living_area         -0.055074      -0.251275
# latitude            -0.041293       0.193398
# longitude            0.025329       0.017744
# Open_fire            0.003509       0.025555
# Swimming_Pool       -0.003961       0.068404
# hasTerrace           0.044873       0.098283
# terraceSurface       0.024312       0.028587
# gardenSurface        0.005251       0.046632
# Number_of_facades   -0.022387       0.083105
# Furnished            1.000000       0.046629
# price_per_sqm        0.046629       1.000000

# %%
# Remove lines where 'Living-area' is = 0
df = df[df['Living_area'] != 0]

df.shape
# Out:
# (5828, 22)

# %%
# Removing unnecessary columns
    #columns_to_drop = ['latitude', 'longitude', 'id', 'Type_of_sale', 'street', 'number']
    #df = df.drop(columns=columns_to_drop, errors='ignore')
df['price_per_sqm'] = df['Price'] / df['Living_area']
df['post_1'] = df['Postal_code'].str[0].astype('int')
df['post_2'] = df['Postal_code'].str[0:2]

df['price_per_sqm'].describe()
# Out:
# count    5828.000000
# mean     2143.006668
# std       692.155621
# min       352.352941
# 25%      1638.022091
# 50%      2100.000000
# 75%      2609.675866
# max      4081.818182
# Name: price_per_sqm, dtype: float64

# %%
df['Living_area'].sort_values
# Out:
# <bound method Series.sort_values of 0       125
# 1       167
# 2       154
# 3       172
# 4       350
#        ...
# 5823    260
# 5824    169
# 5825    237
# 5826    215
# 5827    255
# Name: Living_area, Length: 5828, dtype: int64>

# %%
df['post_1'].describe
# Out:
# <bound method NDFrame.describe of 0       9
# 1       9
# 2       2
# 3       1
# 4       1
#        ..
# 5823    4
# 5824    8
# 5825    1
# 5826    6
# 5827    8
# Name: post_1, Length: 5828, dtype: int64>

# %%
print(df.columns)
# Out:
# Index(['id', 'locality_name', 'Postal_code', 'Price', 'Subtype',
#        'Number_of_bedrooms', 'Living_area', 'street', 'number', 'latitude',
#        'longitude', 'Open_fire', 'Swimming_Pool', 'hasTerrace',
#        'terraceSurface', 'gardenSurface', 'Kitchen_type', 'Number_of_facades',
#        'State_of_building', 'Furnished', 'epc', 'price_per_sqm', 'post_1',
#        'post_2'],
#       dtype='object')

# %%
#cols_to_plot = ['Price', 'Subtype', 'Number_of_bedrooms', 'Living_area', 'Open_fire', 'Swimming_Pool', 'hasTerrace', 'gardenSurface' , 'Kitchen_type','Number_of_facades','State_of_building','Furnished','epc',,,'Furnished','epc',]
cols_to_plot = ['post_1','Number_of_bedrooms', 'Living_area', 'hasTerrace', 'gardenSurface' , 'Kitchen_type','Number_of_facades','State_of_building', 'price_per_sqm', 'Price']
sns.pairplot(df[cols_to_plot], hue='price_per_sqm')
plt.show()

# %%
# Apply the first condition: Flanders or Wallonie
df['region'] = df['Postal_code'].apply(
    lambda x: 'Flanders' if ('1500' < x < '4000') or ('8000' < x <= '9999') else 'Wallonie'
)

# Update 'region' to 'Brussels' for specific postal codes
df['region'] = df.apply(
    lambda row: 'Brussels' if '1000' < row['Postal_code'] < '1300' else row['region'], axis=1
)

# Display the first few rows
df.head()
# Out:
#          id   locality_name Postal_code   Price Subtype  Number_of_bedrooms  \
# 0  20252354           Ronse        9600  319000   House                   3
# 1  20251003  Geraardsbergen        9500  299999   House                   3
# 2  20252002        Mechelen        2800  275000   House                   3
# 3  20252352           Gooik        1755  295000   House                   3
# 4  20250985        Oetingen        1755  560000   House                   4
#
#    Living_area            street number   latitude  longitude  Open_fire  \
# 0          125          Rotterij    148  50.744176   3.625722          0
# 1          167       Pirrestraat     17  50.752121   3.925495          0
# 2          154  Caputsteenstraat    150  51.033269   4.491795          0
# 3          172   Strijlandstraat     45  50.791877   4.084293          0
# 4          350   Blijkheerstraat     70  50.775412   4.047057          0
#
#    Swimming_Pool  hasTerrace  terraceSurface  gardenSurface   Kitchen_type  \
# 0              0           1               0            370            NaN
# 1              0           1               0            895      Installed
# 2              0           1              10             20  Semi equipped
# 3              0           1               0            300            NaN
# 4              0           1              40             32      Installed
#
#    Number_of_facades State_of_building  Furnished epc  price_per_sqm  post_1  \
# 0                  4       To renovate          0   F    2552.000000       9
# 1                  2              Good          0   D    1796.401198       9
# 2                  2       To renovate          0   E    1785.714286       2
# 3                  3       To renovate          0   F    1715.116279       1
# 4                  3              Good          0   C    1600.000000       1
#
#   post_2    region
# 0     96  Flanders
# 1     95  Flanders
# 2     28  Flanders
# 3     17  Flanders
# 4     17  Flanders

# %%
sns.histplot(df, x= 'post_1')
# Out:
# <Axes: xlabel='post_1', ylabel='Count'>

# %%
plotx= sns.histplot(df, x= 'Price', kde=True)
plotx.set(xlim=(0, 900000))
# Out:
# [(0.0, 900000.0)]

# %%
plotx= sns.histplot(df, x= 'Price', kde=True, hue = "post_1")
plotx.set(xlim=(0, 800000))
# Out:
# [(0.0, 800000.0)]

# %%
plotx= sns.histplot(df, x= 'Price', kde=True, hue = "region")
plotx.set(xlim=(0, 800000))
# Out:
# [(0.0, 800000.0)]

# %%
# Group by region and postal code, then calculate the average price
avg_price_per_postal_code = df.groupby(['region', 'Postal_code'])['Price'].mean().reset_index()

# Find the postal code with the highest average price per region
max_avg_price_per_region = avg_price_per_postal_code.loc[
    avg_price_per_postal_code.groupby('region')['Price'].idxmax()
]

# Display the result
print(max_avg_price_per_region)
# Out:
#        region Postal_code     Price
# 4    Brussels        1060  713000.0
# 416  Flanders        9667  775000.0
# 580  Wallonie        5031  749000.0

# %%
# Group by region and calculate the average house price
avg_price_per_region = df.groupby('region')['Price'].mean().reset_index()

# Optional: Format the price values for readability
avg_price_per_region['Price'] = avg_price_per_region['Price'].map('{:,.2f}'.format)

# Display the result
print(avg_price_per_region)
# Out:
#      region       Price
# 0  Brussels  557,816.13
# 1  Flanders  395,159.62
# 2  Wallonie  316,992.65
