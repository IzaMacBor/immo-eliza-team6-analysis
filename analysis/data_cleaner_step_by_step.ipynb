# %% [markdown]
# **DATA CLEANER**

# %%
import pandas as pd
import seaborn as sns
import numpy as np

# Set options to show all columns
pd.set_option('display.max_columns', None)

# Upload csv file
data = r'C:\Users\izama\Desktop\immo_scraper_merged_test.csv' # Fill your path to file
data_scraped = pd.read_csv(data, sep = ',')

# Display first 5 rows
data_scraped.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 10
#       8 # Upload csv file
#       9 data = r'C:\Users\izama\Desktop\immo_scraper_merged_test.csv' # Fill your path to file
# ---> 10 data_scraped = pd.read_csv(data, sep = ',')
#      12 # Display first 5 rows
#      13 data_scraped.head()
#
# File c:\Users\tom_v\becode_projects\3_ImmoWeb_scraper\immo-eliza-team6-analysis\.venv\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\tom_v\becode_projects\3_ImmoWeb_scraper\immo-eliza-team6-analysis\.venv\Lib\site-packages\pandas\io\parsers\readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File c:\Users\tom_v\becode_projects\3_ImmoWeb_scraper\immo-eliza-team6-analysis\.venv\Lib\site-packages\pandas\io\parsers\readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File c:\Users\tom_v\becode_projects\3_ImmoWeb_scraper\immo-eliza-team6-analysis\.venv\Lib\site-packages\pandas\io\parsers\readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File c:\Users\tom_v\becode_projects\3_ImmoWeb_scraper\immo-eliza-team6-analysis\.venv\Lib\site-packages\pandas\io\common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\izama\\Desktop\\immo_scraper_merged_test.csv'

# %%
# Print columns names to list
data_scraped.columns.tolist()
# Out:
# ['id',
#  'locality_name',
#  'Postal_code',
#  'Price',
#  'Subtype',
#  'Number_of_rooms',
#  'Number_of_bedrooms',
#  'Living_area',
#  'sale_annuity',
#  'Type_of_sale',
#  'street',
#  'number',
#  'latitude',
#  'longitude',
#  'Open_fire',
#  'Swimming_Pool',
#  'hasTerrace',
#  'terraceSurface',
#  'hasGarden',
#  'gardenSurface',
#  'Kitchen_type',
#  'Number_of_facades',
#  'State_of_building',
#  'Furnished',
#  'Starting_price',
#  'epc']

# %%
# Adding new column
#data_scraped['price_per_sqm'] = data_scraped['Price'] / data_scraped['Living_area']

# Adding new column of price per m2 with safegaurd for ZeroDivisionError
data_scraped['price_per_sqm'] = np.where(data_scraped['Living_area'] == 0, np.nan, data_scraped['Price'] / data_scraped['Living_area'])

# %%
# Print columns names to list
data_scraped.columns.tolist()
# Out:
# ['id',
#  'locality_name',
#  'Postal_code',
#  'Price',
#  'Subtype',
#  'Number_of_rooms',
#  'Number_of_bedrooms',
#  'Living_area',
#  'sale_annuity',
#  'Type_of_sale',
#  'street',
#  'number',
#  'latitude',
#  'longitude',
#  'Open_fire',
#  'Swimming_Pool',
#  'hasTerrace',
#  'terraceSurface',
#  'hasGarden',
#  'gardenSurface',
#  'Kitchen_type',
#  'Number_of_facades',
#  'State_of_building',
#  'Furnished',
#  'Starting_price',
#  'epc',
#  'price_per_sqm']

# %%
# Edit text in the columns
text_edit_columns = ['Subtype', 'Type_of_sale', 'Kitchen_type', 'State_of_building' ]

for column in text_edit_columns:
    data_scraped[column] = data_scraped[column].astype(str)  # Ensure the column is treated as string
    data_scraped[column] = data_scraped[column].str.replace('_', ' ').str.capitalize() #Replace "_" to space, editing text (first capital letter, rest lower case)

# Display first 5 rows
data_scraped.head()
# Out:
#          id   locality_name Postal_code     Price      Subtype  \
# 0  20252354           RONSE        9600  319000.0        House
# 1  20251003  GERAARDSBERGEN        9500  299999.0        House
# 2  20247788    Tielt (8700)        8700       NaN  House group
# 3  20249506          Deinze        9800       NaN  House group
# 4  20247946          Ninove        9400       NaN  House group
#
#    Number_of_rooms  Number_of_bedrooms  Living_area sale_annuity Type_of_sale  \
# 0              NaN                 3.0        125.0          NaN     For sale
# 1              NaN                 3.0        167.0          NaN     For sale
# 2              NaN                 NaN          NaN          NaN     For sale
# 3              NaN                 NaN          NaN          NaN     For sale
# 4              NaN                 NaN          NaN          NaN     For sale
#
#                    street number   latitude  longitude  Open_fire  \
# 0                Rotterij    148  50.744176   3.625722      False
# 1             Pirrestraat     17  50.752121   3.925495      False
# 2             Kistestraat     13  50.999953   3.322646      False
# 3              Bremkouter  20-28  50.985489   3.585677      False
# 4  Geraardsbergsesteenweg    137  50.855284   3.960070      False
#
#   Swimming_Pool hasTerrace  terraceSurface hasGarden  gardenSurface  \
# 0           NaN       True             NaN      True          370.0
# 1           NaN       True             NaN      True          895.0
# 2           NaN        NaN             NaN       NaN            NaN
# 3           NaN        NaN             NaN       NaN            NaN
# 4           NaN        NaN             NaN       NaN            NaN
#
#   Kitchen_type  Number_of_facades State_of_building Furnished Starting_price  \
# 0          Nan                4.0       To renovate       NaN            NaN
# 1    Installed                2.0              Good       NaN            NaN
# 2          Nan                NaN               Nan       NaN            NaN
# 3          Nan                NaN               Nan       NaN            NaN
# 4          Nan                NaN               Nan       NaN            NaN
#
#    epc  price_per_sqm
# 0    F    2552.000000
# 1    D    1796.401198
# 2  NaN            NaN
# 3  NaN            NaN
# 4  NaN            NaN

# %%
#Edit text of cities and street names
names_edit_columns = ['locality_name', 'street']

for column in names_edit_columns:
    data_scraped[column] = data_scraped[column].astype(str)  # Ensure the column is treated as string
    data_scraped[column] = data_scraped[column].str.title() #Editing text (first scapital letters, rest lower case)

# Remove zip code from brackets, e.g. "Tielt (8700)" -> "Tielt"

data_scraped['locality_name'] = data_scraped['locality_name'].str.replace(r"\s*\(\d+\)", "", regex=True)

# Display first 5 rows
data_scraped.head()
# Out:
#          id   locality_name Postal_code     Price      Subtype  \
# 0  20252354           Ronse        9600  319000.0        House
# 1  20251003  Geraardsbergen        9500  299999.0        House
# 2  20247788           Tielt        8700       NaN  House group
# 3  20249506          Deinze        9800       NaN  House group
# 4  20247946          Ninove        9400       NaN  House group
#
#    Number_of_rooms  Number_of_bedrooms  Living_area sale_annuity Type_of_sale  \
# 0              NaN                 3.0        125.0          NaN     For sale
# 1              NaN                 3.0        167.0          NaN     For sale
# 2              NaN                 NaN          NaN          NaN     For sale
# 3              NaN                 NaN          NaN          NaN     For sale
# 4              NaN                 NaN          NaN          NaN     For sale
#
#                    street number   latitude  longitude  Open_fire  \
# 0                Rotterij    148  50.744176   3.625722      False
# 1             Pirrestraat     17  50.752121   3.925495      False
# 2             Kistestraat     13  50.999953   3.322646      False
# 3              Bremkouter  20-28  50.985489   3.585677      False
# 4  Geraardsbergsesteenweg    137  50.855284   3.960070      False
#
#   Swimming_Pool hasTerrace  terraceSurface hasGarden  gardenSurface  \
# 0           NaN       True             NaN      True          370.0
# 1           NaN       True             NaN      True          895.0
# 2           NaN        NaN             NaN       NaN            NaN
# 3           NaN        NaN             NaN       NaN            NaN
# 4           NaN        NaN             NaN       NaN            NaN
#
#   Kitchen_type  Number_of_facades State_of_building Furnished Starting_price  \
# 0          Nan                4.0       To renovate       NaN            NaN
# 1    Installed                2.0              Good       NaN            NaN
# 2          Nan                NaN               Nan       NaN            NaN
# 3          Nan                NaN               Nan       NaN            NaN
# 4          Nan                NaN               Nan       NaN            NaN
#
#    epc  price_per_sqm
# 0    F    2552.000000
# 1    D    1796.401198
# 2  NaN            NaN
# 3  NaN            NaN
# 4  NaN            NaN

# %%
# Edit the numbers in columns

# Selecting the columns to change
number_edit_columns = ['Number_of_bedrooms', 'Living_area', 'Number_of_facades', 'Price']

# Converting the cell value to int (so that they are integers), if there is no value in the cell - fill in 0.
for column in number_edit_columns:
    data_scraped[column] = pd.to_numeric(data_scraped[column], errors='coerce').fillna(0).astype('Int64')

# Display first 5 rows
data_scraped.head()
# Out:
#          id   locality_name Postal_code   Price      Subtype  Number_of_rooms  \
# 0  20252354           Ronse        9600  319000        House              NaN
# 1  20251003  Geraardsbergen        9500  299999        House              NaN
# 2  20247788           Tielt        8700       0  House group              NaN
# 3  20249506          Deinze        9800       0  House group              NaN
# 4  20247946          Ninove        9400       0  House group              NaN
#
#    Number_of_bedrooms  Living_area sale_annuity Type_of_sale  \
# 0                   3          125          NaN     For sale
# 1                   3          167          NaN     For sale
# 2                   0            0          NaN     For sale
# 3                   0            0          NaN     For sale
# 4                   0            0          NaN     For sale
#
#                    street number   latitude  longitude  Open_fire  \
# 0                Rotterij    148  50.744176   3.625722      False
# 1             Pirrestraat     17  50.752121   3.925495      False
# 2             Kistestraat     13  50.999953   3.322646      False
# 3              Bremkouter  20-28  50.985489   3.585677      False
# 4  Geraardsbergsesteenweg    137  50.855284   3.960070      False
#
#   Swimming_Pool hasTerrace  terraceSurface hasGarden  gardenSurface  \
# 0           NaN       True             NaN      True          370.0
# 1           NaN       True             NaN      True          895.0
# 2           NaN        NaN             NaN       NaN            NaN
# 3           NaN        NaN             NaN       NaN            NaN
# 4           NaN        NaN             NaN       NaN            NaN
#
#   Kitchen_type  Number_of_facades State_of_building Furnished Starting_price  \
# 0          Nan                  4       To renovate       NaN            NaN
# 1    Installed                  2              Good       NaN            NaN
# 2          Nan                  0               Nan       NaN            NaN
# 3          Nan                  0               Nan       NaN            NaN
# 4          Nan                  0               Nan       NaN            NaN
#
#    epc  price_per_sqm
# 0    F    2552.000000
# 1    D    1796.401198
# 2  NaN            NaN
# 3  NaN            NaN
# 4  NaN            NaN

# %%
# Replace 'True', 'False' and empty cells value on binary values

columns_for_change_01 = ['Open_fire', 'Swimming_Pool', 'Furnished', 'hasTerrace'] #Columns for change

# Values conversion cells from false to 0, true to 1, if empty fill as 0.
data_scraped[columns_for_change_01] = data_scraped[columns_for_change_01].replace({False:0, True:1}).fillna(0).astype('Int64')

# Display first 5 rows
data_scraped.head()
# Out:
# C:\Users\izama\AppData\Local\Temp\ipykernel_9500\1979093822.py:6: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data_scraped[columns_for_change_01] = data_scraped[columns_for_change_01].replace({False:0, True:1}).fillna(0).astype('Int64')
#          id   locality_name Postal_code   Price      Subtype  Number_of_rooms  \
# 0  20252354           Ronse        9600  319000        House              NaN
# 1  20251003  Geraardsbergen        9500  299999        House              NaN
# 2  20247788           Tielt        8700       0  House group              NaN
# 3  20249506          Deinze        9800       0  House group              NaN
# 4  20247946          Ninove        9400       0  House group              NaN
#
#    Number_of_bedrooms  Living_area sale_annuity Type_of_sale  \
# 0                   3          125          NaN     For sale
# 1                   3          167          NaN     For sale
# 2                   0            0          NaN     For sale
# 3                   0            0          NaN     For sale
# 4                   0            0          NaN     For sale
#
#                    street number   latitude  longitude  Open_fire  \
# 0                Rotterij    148  50.744176   3.625722          0
# 1             Pirrestraat     17  50.752121   3.925495          0
# 2             Kistestraat     13  50.999953   3.322646          0
# 3              Bremkouter  20-28  50.985489   3.585677          0
# 4  Geraardsbergsesteenweg    137  50.855284   3.960070          0
#
#    Swimming_Pool  hasTerrace  terraceSurface hasGarden  gardenSurface  \
# 0              0           1             NaN      True          370.0
# 1              0           1             NaN      True          895.0
# 2              0           0             NaN       NaN            NaN
# 3              0           0             NaN       NaN            NaN
# 4              0           0             NaN       NaN            NaN
#
#   Kitchen_type  Number_of_facades State_of_building  Furnished Starting_price  \
# 0          Nan                  4       To renovate          0            NaN
# 1    Installed                  2              Good          0            NaN
# 2          Nan                  0               Nan          0            NaN
# 3          Nan                  0               Nan          0            NaN
# 4          Nan                  0               Nan          0            NaN
#
#    epc  price_per_sqm
# 0    F    2552.000000
# 1    D    1796.401198
# 2  NaN            NaN
# 3  NaN            NaN
# 4  NaN            NaN

# %%
# Edit area's cells

# Columns for change
columns_for_change_m2 = ['Living_area', 'terraceSurface', 'gardenSurface']

# Change string value to an integer
for col in columns_for_change_m2:
    data_scraped[col] = pd.to_numeric(data_scraped[col], errors='coerce').fillna(0).astype('Int64')

#Add m² to the area values
#for col in columns_for_change_m2:
#    data_scraped[col] = data_scraped[col].apply(lambda x: f"{x} m²" if pd.notna(x) and x != 0 else x) 

# Display first 5 rows
data_scraped.head()
# Out:
#          id   locality_name Postal_code   Price      Subtype  Number_of_rooms  \
# 0  20252354           Ronse        9600  319000        House              NaN
# 1  20251003  Geraardsbergen        9500  299999        House              NaN
# 2  20247788           Tielt        8700       0  House group              NaN
# 3  20249506          Deinze        9800       0  House group              NaN
# 4  20247946          Ninove        9400       0  House group              NaN
#
#    Number_of_bedrooms  Living_area sale_annuity Type_of_sale  \
# 0                   3          125          NaN     For sale
# 1                   3          167          NaN     For sale
# 2                   0            0          NaN     For sale
# 3                   0            0          NaN     For sale
# 4                   0            0          NaN     For sale
#
#                    street number   latitude  longitude  Open_fire  \
# 0                Rotterij    148  50.744176   3.625722          0
# 1             Pirrestraat     17  50.752121   3.925495          0
# 2             Kistestraat     13  50.999953   3.322646          0
# 3              Bremkouter  20-28  50.985489   3.585677          0
# 4  Geraardsbergsesteenweg    137  50.855284   3.960070          0
#
#    Swimming_Pool  hasTerrace  terraceSurface hasGarden  gardenSurface  \
# 0              0           1               0      True            370
# 1              0           1               0      True            895
# 2              0           0               0       NaN              0
# 3              0           0               0       NaN              0
# 4              0           0               0       NaN              0
#
#   Kitchen_type  Number_of_facades State_of_building  Furnished Starting_price  \
# 0          Nan                  4       To renovate          0            NaN
# 1    Installed                  2              Good          0            NaN
# 2          Nan                  0               Nan          0            NaN
# 3          Nan                  0               Nan          0            NaN
# 4          Nan                  0               Nan          0            NaN
#
#    epc  price_per_sqm
# 0    F    2552.000000
# 1    D    1796.401198
# 2  NaN            NaN
# 3  NaN            NaN
# 4  NaN            NaN

# %%
# Replace "0" and "Nan" on "Null"

# Columns for change
columns_for_change_null = ['hasGarden', 'epc', 'Kitchen_type', 'State_of_building']

# Reaplace 0 and Nan on 'null'
data_scraped[columns_for_change_null] = data_scraped[columns_for_change_null].replace({0: 'null', 'Nan': 'null'})

# Empty cells fill as 'null'
data_scraped[columns_for_change_null] = data_scraped[columns_for_change_null].fillna('null')

# Display first 5 rows
data_scraped.head()
# Out:
#          id   locality_name Postal_code   Price      Subtype  Number_of_rooms  \
# 0  20252354           Ronse        9600  319000        House              NaN
# 1  20251003  Geraardsbergen        9500  299999        House              NaN
# 2  20247788           Tielt        8700       0  House group              NaN
# 3  20249506          Deinze        9800       0  House group              NaN
# 4  20247946          Ninove        9400       0  House group              NaN
#
#    Number_of_bedrooms  Living_area sale_annuity Type_of_sale  \
# 0                   3          125          NaN     For sale
# 1                   3          167          NaN     For sale
# 2                   0            0          NaN     For sale
# 3                   0            0          NaN     For sale
# 4                   0            0          NaN     For sale
#
#                    street number   latitude  longitude  Open_fire  \
# 0                Rotterij    148  50.744176   3.625722          0
# 1             Pirrestraat     17  50.752121   3.925495          0
# 2             Kistestraat     13  50.999953   3.322646          0
# 3              Bremkouter  20-28  50.985489   3.585677          0
# 4  Geraardsbergsesteenweg    137  50.855284   3.960070          0
#
#    Swimming_Pool  hasTerrace  terraceSurface hasGarden  gardenSurface  \
# 0              0           1               0      True            370
# 1              0           1               0      True            895
# 2              0           0               0      null              0
# 3              0           0               0      null              0
# 4              0           0               0      null              0
#
#   Kitchen_type  Number_of_facades State_of_building  Furnished Starting_price  \
# 0         null                  4       To renovate          0            NaN
# 1    Installed                  2              Good          0            NaN
# 2         null                  0              null          0            NaN
# 3         null                  0              null          0            NaN
# 4         null                  0              null          0            NaN
#
#     epc  price_per_sqm
# 0     F    2552.000000
# 1     D    1796.401198
# 2  null            NaN
# 3  null            NaN
# 4  null            NaN

# %%
# Checking how many rows there are in a data frame
data_scraped.shape[0]
# Out:
# 9989

# %%
# Remove lines where 'Starting_price' is True
data_scraped = data_scraped[data_scraped['Starting_price'] != True]

# Remove lines where 'Price' is = 0
data_scraped = data_scraped[data_scraped['Price'] != 0]

# Remove lines where 'Living area' is = 0
data_scraped = data_scraped[data_scraped['Living_area'] != 0]

# Remove lines where 'Number_of_bedrooms' is = 0
data_scraped = data_scraped[data_scraped['Number_of_bedrooms'] != 0]


# Display first 5 rows
data_scraped.head()
# Out:
#           id         locality_name Postal_code   Price          Subtype  \
# 0   20252354                 Ronse        9600  319000            House
# 1   20251003        Geraardsbergen        9500  299999            House
# 8   20252002              Mechelen        2800  275000            House
# 9   20252352                 Gooik        1755  295000            House
# 18  20250577  Sint-Katelijne-Waver        2860  345000  Apartment block
#
#     Number_of_rooms  Number_of_bedrooms  Living_area sale_annuity  \
# 0               NaN                   3          125          NaN
# 1               NaN                   3          167          NaN
# 8               NaN                   3          154          NaN
# 9               NaN                   3          172          NaN
# 18              NaN                   1           43          NaN
#
#    Type_of_sale            street number   latitude  longitude  Open_fire  \
# 0      For sale          Rotterij    148  50.744176   3.625722          0
# 1      For sale       Pirrestraat     17  50.752121   3.925495          0
# 8      For sale  Caputsteenstraat    150  51.033269   4.491795          0
# 9      For sale   Strijlandstraat     45  50.791877   4.084293          0
# 18     For sale       Ijzerenveld      4  51.034950   4.511372          0
#
#     Swimming_Pool  hasTerrace  terraceSurface hasGarden  gardenSurface  \
# 0               0           1               0      True            370
# 1               0           1               0      True            895
# 8               0           1              10      True             20
# 9               0           1               0      True            300
# 18              0           1               4      null              0
#
#      Kitchen_type  Number_of_facades State_of_building  Furnished  \
# 0            null                  4       To renovate          0
# 1       Installed                  2              Good          0
# 8   Semi equipped                  2       To renovate          0
# 9            null                  3       To renovate          0
# 18           null                  2              Good          0
#
#    Starting_price epc  price_per_sqm
# 0             NaN   F    2552.000000
# 1             NaN   D    1796.401198
# 8             NaN   E    1785.714286
# 9             NaN   F    1715.116279
# 18            NaN   B    8023.255814

# %%
# Checking how many rows there are in a data frame after remove
data_scraped.shape[0]
# Out:
# 8328

# %%
#Checks values in column
data_scraped['Subtype'].value_counts()
# Out:
# Subtype
# House                   6153
# Villa                    946
# Mixed use building       304
# Apartment block          232
# Mansion                  171
# Exceptional property     171
# Town house               104
# Bungalow                  88
# Country cottage           85
# Farmhouse                 41
# Chalet                    13
# Manor house               10
# Castle                     8
# Other property             2
# Name: count, dtype: int64

# %% [markdown]
# These property types—'House group', 'Mixed use building', 'Apartment block', 'Castle', 'Other property', 'Exceptional property'—are not used our my analysis of housing and apartment prices because they represent categories that are either too broad, non-residential, or highly specialized. Including them would introduce significant variability and outliers, making it difficult to accurately assess market trends for standard residential properties like single-family homes or apartments. My analysis focuses on more typical housing types to ensure relevance and consistency in the data.

# %%
# Cleaning data from unnecessary subtypes

values_to_remove = ['House group','Mixed use building', 'Apartment block', 'Castle', 'Other property', 'Exceptional property']
data_scraped = data_scraped[~data_scraped['Subtype'].isin(values_to_remove)]

# Display first 5 rows
data_scraped.head()
# Out:
#           id   locality_name Postal_code   Price Subtype  Number_of_rooms  \
# 0   20252354           Ronse        9600  319000   House              NaN
# 1   20251003  Geraardsbergen        9500  299999   House              NaN
# 8   20252002        Mechelen        2800  275000   House              NaN
# 9   20252352           Gooik        1755  295000   House              NaN
# 20  20250985        Oetingen        1755  560000   House              NaN
#
#     Number_of_bedrooms  Living_area sale_annuity Type_of_sale  \
# 0                    3          125          NaN     For sale
# 1                    3          167          NaN     For sale
# 8                    3          154          NaN     For sale
# 9                    3          172          NaN     For sale
# 20                   4          350          NaN     For sale
#
#               street number   latitude  longitude  Open_fire  Swimming_Pool  \
# 0           Rotterij    148  50.744176   3.625722          0              0
# 1        Pirrestraat     17  50.752121   3.925495          0              0
# 8   Caputsteenstraat    150  51.033269   4.491795          0              0
# 9    Strijlandstraat     45  50.791877   4.084293          0              0
# 20   Blijkheerstraat     70  50.775412   4.047057          0              0
#
#     hasTerrace  terraceSurface hasGarden  gardenSurface   Kitchen_type  \
# 0            1               0      True            370           null
# 1            1               0      True            895      Installed
# 8            1              10      True             20  Semi equipped
# 9            1               0      True            300           null
# 20           1              40      True             32      Installed
#
#     Number_of_facades State_of_building  Furnished Starting_price epc  \
# 0                   4       To renovate          0            NaN   F
# 1                   2              Good          0            NaN   D
# 8                   2       To renovate          0            NaN   E
# 9                   3       To renovate          0            NaN   F
# 20                  3              Good          0            NaN   C
#
#     price_per_sqm
# 0     2552.000000
# 1     1796.401198
# 8     1785.714286
# 9     1715.116279
# 20    1600.000000

# %%
#Checks values in column after cleaning
data_scraped['Subtype'].value_counts()
# Out:
# Subtype
# House              6153
# Villa               946
# Mansion             171
# Town house          104
# Bungalow             88
# Country cottage      85
# Farmhouse            41
# Chalet               13
# Manor house          10
# Name: count, dtype: int64

# %%
# Checking how many rows there are in a data frame after second remove
data_scraped.shape[0]
# Out:
# 7611

# %%
# Checking how many columns there are in a data frame
data_scraped.shape[1]
# Out:
# 27

# %%
# Removing unnecessary columns

columns_to_drop = ['Number_of_rooms', 'sale_annuity', 'Starting_price', 'Type_of_sale', 'hasGarden']
data_scraped = data_scraped.drop(columns=columns_to_drop, errors='ignore')

# Display first 5 rows
data_scraped.head()
# Out:
#           id   locality_name Postal_code   Price Subtype  Number_of_bedrooms  \
# 0   20252354           Ronse        9600  319000   House                   3
# 1   20251003  Geraardsbergen        9500  299999   House                   3
# 8   20252002        Mechelen        2800  275000   House                   3
# 9   20252352           Gooik        1755  295000   House                   3
# 20  20250985        Oetingen        1755  560000   House                   4
#
#     Living_area            street number   latitude  longitude  Open_fire  \
# 0           125          Rotterij    148  50.744176   3.625722          0
# 1           167       Pirrestraat     17  50.752121   3.925495          0
# 8           154  Caputsteenstraat    150  51.033269   4.491795          0
# 9           172   Strijlandstraat     45  50.791877   4.084293          0
# 20          350   Blijkheerstraat     70  50.775412   4.047057          0
#
#     Swimming_Pool  hasTerrace  terraceSurface  gardenSurface   Kitchen_type  \
# 0               0           1               0            370           null
# 1               0           1               0            895      Installed
# 8               0           1              10             20  Semi equipped
# 9               0           1               0            300           null
# 20              0           1              40             32      Installed
#
#     Number_of_facades State_of_building  Furnished epc  price_per_sqm
# 0                   4       To renovate          0   F    2552.000000
# 1                   2              Good          0   D    1796.401198
# 8                   2       To renovate          0   E    1785.714286
# 9                   3       To renovate          0   F    1715.116279
# 20                  3              Good          0   C    1600.000000

# %%
# Checking how many columns there are in a data frame after remove
data_scraped.shape[1]
# Out:
# 22

# %% [markdown]
# **CLEANING DATA FROM DUPLICATES**

# %%
# Check which rows are duplicates (indicates True for duplicates)

cleaned_data = data_scraped.drop_duplicates(subset=['latitude', 'longitude', 'street', 'number', 'Subtype'])
duplicates = data_scraped[data_scraped.duplicated(subset=['latitude', 'longitude', 'street', 'number', 'Subtype'])]

print(duplicates)
# Out:
#             id       locality_name Postal_code    Price Subtype  \
# 38    20236560          Borgerhout        2140   389900   House
# 42    20249528               Ronse        9600   325500   House
# 119   20251655           Rochefort        5580   149000   House
# 121   20251399          Oudenaarde        9700   165000   House
# 122   20251655           Rochefort        5580   149000   House
# ...        ...                 ...         ...      ...     ...
# 9951  20220161         Châtelineau        6200    85000   House
# 9952  20220329              Astene        9800   420000   House
# 9965  20231733  Rhode-Saint-Genese        1640  3495000   House
# 9979  20142785          Londerzeel        1840   285000   House
# 9980  20204784            Overijse        3090   290000   House
#
#       Number_of_bedrooms  Living_area            street number   latitude  \
# 38                     3          150       Kroonstraat    134  51.212485
# 42                     3          122          Rotterij    148  50.744176
# 119                    4          305  Rue De La Lhomme      1  50.162502
# 121                    3          117      Heurnestraat    100  50.874806
# 122                    4          305  Rue De La Lhomme      1  50.162502
# ...                  ...          ...               ...    ...        ...
# 9951                   2          100               Nan    NaN        NaN
# 9952                   3          187               Nan    NaN        NaN
# 9965                   5          500               Nan    NaN        NaN
# 9979                   2           98    Stationsstraat     35  51.005983
# 9980                   3          108               Nan    NaN        NaN
#
#       longitude  Open_fire  Swimming_Pool  hasTerrace  terraceSurface  \
# 38     4.429373          0              0           1               5
# 42     3.625722          0              0           1              16
# 119    5.260235          0              0           1              16
# 121    3.622556          0              0           1               0
# 122    5.260235          0              0           1              16
# ...         ...        ...            ...         ...             ...
# 9951        NaN          0              0           1               5
# 9952        NaN          0              0           0               0
# 9965        NaN          0              0           0               0
# 9979   4.301927          0              0           0               0
# 9980        NaN          0              0           1              12
#
#       gardenSurface    Kitchen_type  Number_of_facades State_of_building  \
# 38               19  Hyper equipped                  2    Just renovated
# 42              370  Hyper equipped                  4     To be done up
# 119               0   Not installed                  3     To be done up
# 121               0            null                  0       To renovate
# 122               0   Not installed                  3     To be done up
# ...             ...             ...                ...               ...
# 9951             50            null                  2       To renovate
# 9952              0       Installed                  4              Good
# 9965           1500            null                  4              Good
# 9979              0            null                  2              null
# 9980             86   Not installed                  2       To renovate
#
#       Furnished epc  price_per_sqm
# 38            0   C    2599.333333
# 42            0   F    2668.032787
# 119           0   C     488.524590
# 121           1   F    1410.256410
# 122           0   C     488.524590
# ...         ...  ..            ...
# 9951          0   G     850.000000
# 9952          0   F    2245.989305
# 9965          0   A    6990.000000
# 9979          0   D    2908.163265
# 9980          0   E    2685.185185
#
# [665 rows x 22 columns]

# %%
# Checking how many rows there are in a data frame after removing duplicates
cleaned_data.shape[0]
# Out:
# 6946

# %% [markdown]
# **CLEANING DATA FROM OUTLINERS**

# %% [markdown]
# **Z-score method**

# %%
# to see outliners from Number_of_bedrooms in boxplot

sns.boxplot(x=cleaned_data['Number_of_bedrooms'], orient='h')
# Out:
# <Axes: xlabel='Number_of_bedrooms'>

# %%
upper_limit = cleaned_data['Number_of_bedrooms'].mean() + 4*cleaned_data['Number_of_bedrooms'].std()

lower_limit = cleaned_data['Number_of_bedrooms'].mean() - 4*cleaned_data['Number_of_bedrooms'].std()

print('upper limit:', upper_limit)
print('lower limit:', lower_limit)
# Out:
# upper limit: 8.695551361957364
# lower limit: -1.5115605758934412

# %%
# find the ouliner

cleaned_data.loc[(cleaned_data['Number_of_bedrooms'] > upper_limit) | (cleaned_data['Number_of_bedrooms'] < lower_limit)]
# Out:
#             id                  locality_name Postal_code    Price    Subtype  \
# 323   20240646           Woluwe-Saint-Lambert        1200   790000      House
# 877   20246583                   Grez-Doiceau        1390   649000      House
# 2426  20246971                           Gent        9000   649000    Mansion
# 3195  20150570                          Ieper        8900   719000      House
# 4903  20152610                          Wavre        1300   695000      House
# 4916  20141889                Corroy-Le-Grand        1325  1395000      Villa
# 5044  20133161                          Ronse        9600   449000    Mansion
# 5094  20122032                         Herent        3020   825000    Mansion
# 5713  20191677                          Menen        8930   650000    Mansion
# 5983  20099588                           Gent        9000  1150000      House
# 6437  11021515                     Anderlecht        1070   900000      House
# 6447  11211836  Sint-Pieters-Leeuw Vlezenbeek        1602  1200000      House
# 6539  20218685                            Huy        4500   400000      House
# 6628  20215116                      Beauraing        5570   350000      House
# 6671  20197142                     Lambermont        4800   395000    Mansion
# 6933  10432397                  Sint-Michiels        8200   770000      House
# 7023  20180983                      Assebroek        8310  1999999      House
# 7050  20190524                         Leuven        3000  1595000    Mansion
# 7099  20226411                            Eke        9810   350000      House
# 7470  20093289                      Vloesberg        7880  1095000      House
# 7475  11145232                     Orp-Jauche        1350  1275000      House
# 7506  20212224                      Rochefort        5580   290000      House
# 8000  10687336                         Laeken        1020   900000    Mansion
# 8538  20071216                   Lichtervelde        8810   795000      House
# 8539  20071208                   Lichtervelde        8810   795000  Farmhouse
# 8544  11098159                       Nivelles        1400   845000      House
# 8548  20127827                     Brasschaat        2930   850000      Villa
# 8588   9750633                     Carlsbourg        6850  1650000      House
# 8599  11137709            Woluwe-Saint-Pierre        1150  2500000      House
# 9081  20126378                          Ronse        9600   449000      House
# 9156  11014049                        Lebbeke        9280   725000      House
# 9208  10938382                     Oudsbergen        3670  1199000      Villa
# 9217  11426888                     Oudenaarde        9700  1295000    Mansion
# 9226  11463994                           Gent        9000  1600000      House
# 9476  20198514                    Dendermonde        9200  1495000      House
#
#       Number_of_bedrooms  Living_area                               street  \
# 323                   10          362                    Avenue De Juillet
# 877                   10          407                  Petite Rue Des Prés
# 2426                  10          319                      Wijngaardstraat
# 3195                  12          559                         Colaertplein
# 4903                   9          420                   Avenue Montesquieu
# 4916                  10          510                      Rue Du Warichet
# 5044                  16         1350                        Olifantstraat
# 5094                  11          669                     Wilselsesteenweg
# 5713                   9          683                          Ieperstraat
# 5983                  15          950                             Geldmunt
# 6437                   9          270                     Chaussée De Mons
# 6447                  12          350                              Postweg
# 6539                  13         1600                     Place Du Tilleul
# 6628                  16          520  Givet -France , Route De Bonsecours
# 6671                   9          918                       Rue Francomont
# 6933                  12          382                          Dorpsstraat
# 7023                   9          658                          Wantestraat
# 7050                  11          268                 Blijde-Inkomststraat
# 7099                   9          300                             Steenweg
# 7470                  10          384                             Paillart
# 7475                  17          950               Rue Brou De Gentissart
# 7506                  11          335                          Rue Jacquet
# 8000                   9          285                       Square Léopold
# 8538                  10          510                       Oude Bruggeweg
# 8539                  10          510                       Oude Bruggeweg
# 8544                  12          505                      Située À Ittres
# 8548                  16          847                            Bredabaan
# 8588                   9          850                    Merny - Grand Rue
# 8599                  20          750                        Avenue Orban
# 9081                  16         1333                        Olifantstraat
# 9156                   9          532                     Leo Duboisstraat
# 9208                   9          773                           Roesstraat
# 9217                  12         1000                           Hoogstraat
# 9226                  15         1208              Sint-Lievenspoortstraat
# 9476                  16          800                       Lindanusstraat
#
#        number   latitude  longitude  Open_fire  Swimming_Pool  hasTerrace  \
# 323        44  50.847921   4.414961          0              0           1
# 877         6  50.738804   4.661776          0              0           1
# 2426       18  51.048431   3.718139          0              0           0
# 3195        5  50.849124   2.877171          0              0           0
# 4903       25  50.714741   4.634883          0              0           1
# 4916       12  50.666398   4.671964          0              0           1
# 5044    24-26  50.745185   3.605262          0              0           1
# 5094        9  50.905929   4.674694          0              0           1
# 5713      102  50.797566   3.114622          0              0           0
# 5983       22  51.057414   3.721374          0              0           0
# 6437     1199  50.820105   4.292984          0              0           1
# 6447       13  50.813056   4.256253          0              0           1
# 6539        7  50.514404   5.236613          0              0           0
# 6628  128-130  50.148602   4.824084          0              0           0
# 6671        7  50.583730   5.837587          0              0           1
# 6933      121  51.187665   3.214165          0              0           1
# 7023       30  51.195458   3.234129          0              1           1
# 7050       10  50.877307   4.707509          0              0           1
# 7099       32  50.952890   3.641102          0              0           0
# 7470      6-8  50.762169   3.710028          1              0           0
# 7475        3  50.704155   4.931218          0              0           1
# 7506       27  50.156457   5.222608          1              0           1
# 8000       27  50.883744   4.339256          0              0           1
# 8538       33  51.042547   3.148634          0              0           0
# 8539       33  51.042547   3.148634          0              0           0
# 8544        .  50.588657   4.330865          1              0           0
# 8548      714  51.318706   4.517522          1              0           0
# 8588       80  49.898231   5.091934          0              0           1
# 8599       82  50.834406   4.455508          0              0           1
# 9081       26  50.745308   3.605382          0              0           1
# 9156       48  50.998852   4.123377          0              0           1
# 9208       13  51.104426   5.608801          0              0           0
# 9217      2-4  50.844417   3.602487          0              0           1
# 9226      142  51.042274   3.736050          0              0           1
# 9476       33  51.028666   4.102995          0              0           1
#
#       terraceSurface  gardenSurface    Kitchen_type  Number_of_facades  \
# 323                5             50  Hyper equipped                  2
# 877               10              0       Installed                  4
# 2426               0            126            null                  2
# 3195               0            340            null                  2
# 4903               0              0       Installed                  4
# 4916              64           3752  Hyper equipped                  4
# 5044               0              0   Semi equipped                  2
# 5094               0              0       Installed                  2
# 5713               0              0            null                  0
# 5983               0             23       Installed                  3
# 6437              30             60  Hyper equipped                  2
# 6447             100            800  Hyper equipped                  3
# 6539               0              0            null                  0
# 6628               0            547            null                  0
# 6671             130            660       Installed                  2
# 6933               0            190            null                  2
# 7023               0           2900  Hyper equipped                  2
# 7050               0              0       Installed                  0
# 7099               0              0            null                  0
# 7470               0              0            null                  4
# 7475             100           5000            null                  6
# 7506               0              0            null                  0
# 8000              18            105  Hyper equipped                  3
# 8538               0           1000       Installed                  0
# 8539               0           1000       Installed                  0
# 8544               0              0            null                  4
# 8548               0              0   Semi equipped                  4
# 8588               0              0       Installed                  4
# 8599               0            977  Hyper equipped                  3
# 9081               0              0  Hyper equipped                  2
# 9156               0              0            null                  4
# 9208               0              0            null                  4
# 9217               0              0       Installed                  0
# 9226               0              0            null                  4
# 9476               0              0  Hyper equipped                  2
#
#      State_of_building  Furnished   epc  price_per_sqm
# 323        To renovate          0     G    2182.320442
# 877        To renovate          0     D    1594.594595
# 2426       To renovate          0     D    2034.482759
# 3195       To renovate          0     F    1286.225403
# 4903              Good          0     C    1654.761905
# 4916            As new          0     D    2735.294118
# 5044       To renovate          0     E     332.592593
# 5094     To be done up          0     F    1233.183857
# 5713              Good          0     B     951.683748
# 5983        To restore          0     F    1210.526316
# 6437    Just renovated          0     F    3333.333333
# 6447    Just renovated          0     E    3428.571429
# 6539              Good          0  null     250.000000
# 6628              Good          0     D     673.076923
# 6671       To renovate          0     F     430.283224
# 6933            As new          0     D    2015.706806
# 7023            As new          0     C    3039.512158
# 7050              Good          1     C    5951.492537
# 7099              null          0     B    1166.666667
# 7470     To be done up          0     C    2851.562500
# 7475              Good          0     B    1342.105263
# 7506       To renovate          0     F     865.671642
# 8000            As new          0     G    3157.894737
# 8538              Good          1     C    1558.823529
# 8539              Good          1     C    1558.823529
# 8544       To renovate          0     E    1673.267327
# 8548       To renovate          0     F    1003.541913
# 8588            As new          1     B    1941.176471
# 8599     To be done up          0  null    3333.333333
# 9081       To renovate          0     E     336.834209
# 9156     To be done up          0     E    1362.781955
# 9208            As new          0     E    1551.099612
# 9217              Good          1     B    1295.000000
# 9226              Good          0     G    1324.503311
# 9476    Just renovated          0     C    1868.750000

# %%
# remove outliers

clened_data_without_outliers = cleaned_data.loc[(cleaned_data['Number_of_bedrooms'] < upper_limit) & (cleaned_data['Number_of_bedrooms'] > lower_limit)]
print('befor removing outliers:', len(cleaned_data))
print('after removing outliers:', len(clened_data_without_outliers))
print('outliers:', len(cleaned_data) - len(clened_data_without_outliers))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 3
#       1 # remove outliers
# ----> 3 clened_data_without_outliers = cleaned_data.loc[(cleaned_data['Number_of_bedrooms'] < upper_limit) & (cleaned_data['Number_of_bedrooms'] > lower_limit)]
#       4 print('befor removing outliers:', len(cleaned_data))
#       5 print('after removing outliers:', len(clened_data_without_outliers))
#
# NameError: name 'cleaned_data' is not defined

# %%
# to see outliners from Number_of_bedrooms in boxplot

sns.boxplot(x=clened_data_without_outliers['Number_of_bedrooms'], orient='h')
# Out:
# <Axes: xlabel='Number_of_bedrooms'>

# %%
clened_data_without_outliers['Number_of_bedrooms'].agg(['count','skew','mean','median'])
# Out:
# count     6911.000000
# skew         0.817543
# mean         3.550427
# median       3.000000
# Name: Number_of_bedrooms, dtype: float64

# %%
# to see outliners from Living area in boxplot

sns.boxplot(x=clened_data_without_outliers['Living_area'], orient='h')
# Out:
# <Axes: xlabel='Living_area'>

# %%
# Outliers by 'Living area' column, checked via IQR.

# In this method, we determine quartile values ​​Q1 (25th percentile) and Q3 (75th percentile) and then cal
# Outliers are those that fall outside the range [Q1 - 1.5 * IQR, Q3 + 1.5 * IQR]

q1 = clened_data_without_outliers['Living_area'].quantile(0.25)
q3 = clened_data_without_outliers['Living_area'].quantile(0.75)
iqr = q3 - q1

# Specifying the scope of outliners
lower_bound = q1 - 1.5 * iqr
upper_bound = q3 + 1.5 * iqr

# Data filtering
clened_data_without_outliers = clened_data_without_outliers[(clened_data_without_bedrooms_outliers['Living_area'] >= lower_bound) & 
                            (clened_data_without_outliers['Living_area'] <= upper_bound)]

# Display first 5 rows
clened_data_without_outliers['Living_area'].value_counts

sns.boxplot(x=clened_data_without_outliers['Living_area'], orient='h')
clened_data_without_outliers['Living_area'].agg(['count','skew','mean','median'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 6
#       1 # Outliers by 'Living area' column, checked via IQR.
#       2
#       3 # In this method, we determine quartile values ​​Q1 (25th percentile) and Q3 (75th percentile) and then cal
#       4 # Outliers are those that fall outside the range [Q1 - 1.5 * IQR, Q3 + 1.5 * IQR]
# ----> 6 q1 = clened_data_without_outliers['Living_area'].quantile(0.25)
#       7 q3 = clened_data_without_outliers['Living_area'].quantile(0.75)
#       8 iqr = q3 - q1
#
# NameError: name 'clened_data_without_outliers' is not defined

# %%
# to see outliners from Price in boxplot

sns.boxplot(x=clened_data_without_outliers['Price'], orient='h')
# Out:
# <Axes: xlabel='Price'>

# %%
# Outliers by 'Price' column, checked via IQR.

# In this method, we determine quartile values ​​Q1 (25th percentile) and Q3 (75th percentile) and then cal
# Outliers are those that fall outside the range [Q1 - 1.5 * IQR, Q3 + 1.5 * IQR]

q1 = clened_data_without_outliers['Price'].quantile(0.25)
q3 = clened_data_without_outliers['Price'].quantile(0.75)
iqr = q3 - q1

# Specifying the scope of outliners
lower_bound = q1 - 1.5 * iqr
upper_bound = q3 + 1.5 * iqr

# Data filtering
clened_data_without_outliers = clened_data_without_outliers[(clened_data_without_outliers['Price'] >= lower_bound) & 
                            (clened_data_without_outliers['Price'] <= upper_bound)]



sns.boxplot(x=clened_data_without_outliers['Price'], orient='h')
clened_data_without_outliers['Price'].agg(['count','skew','mean','median'])
# Out:
# count       5845.000000
# skew           0.582481
# mean      383603.505389
# median    365000.000000
# Name: Price, dtype: float64

# %%
# to see outliners from Price in boxplot

sns.boxplot(x=clened_data_without_outliers['price_per_sqm'], orient='h')
# Out:
# <Axes: xlabel='price_per_sqm'>

# %%
# Outliers by 'Price' column, checked via IQR.

# In this method, we determine quartile values ​​Q1 (25th percentile) and Q3 (75th percentile) and then cal
# Outliers are those that fall outside the range [Q1 - 1.5 * IQR, Q3 + 1.5 * IQR]

q1 = clened_data_without_outliers['price_per_sqm'].quantile(0.25)
q3 = clened_data_without_outliers['price_per_sqm'].quantile(0.75)
iqr = q3 - q1

# Specifying the scope of outliners
lower_bound = q1 - 1.5 * iqr
upper_bound = q3 + 1.5 * iqr

# Data filtering
clened_data_without_outliers = clened_data_without_outliers[(clened_data_without_outliers['price_per_sqm'] >= lower_bound) & 
                            (clened_data_without_outliers['price_per_sqm'] <= upper_bound)]



sns.boxplot(x=clened_data_without_outliers['price_per_sqm'], orient='h')
clened_data_without_outliers['price_per_sqm'].agg(['count','skew','mean','median'])
# Out:
# count     5828.000000
# skew         0.280996
# mean      2143.006668
# median    2100.000000
# Name: price_per_sqm, dtype: float64

# %%
# to see outliners from terrace surface in boxplot

#sns.boxplot(x=clened_data_without_bedrooms_outliers['terraceSurface'], orient='h')
# Out:
# <Axes: xlabel='terraceSurface'>

# %%
# Outliers by 'teracce surface' column, checked via IQR.

# In this method, we determine quartile values ​​Q1 (25th percentile) and Q3 (75th percentile) and then cal
# Outliers are those that fall outside the range [Q1 - 1.5 * IQR, Q3 + 1.5 * IQR]

#q1 = clened_data_without_bedrooms_outliers['terraceSurface'].quantile(0.25)
#q3 = clened_data_without_bedrooms_outliers['terraceSurface'].quantile(0.75)
#iqr = q3 - q1

# Specifying the scope of outliners
#lower_bound = q1 - 1.5 * iqr
#upper_bound = q3 + 1.5 * iqr

# Data filtering
#clened_data_without_bedrooms_outliers = clened_data_without_bedrooms_outliers[(clened_data_without_bedrooms_outliers['terraceSurface'] >= lower_bound) & 
#                            (clened_data_without_bedrooms_outliers['terraceSurface'] <= upper_bound)]



#sns.boxplot(x=clened_data_without_bedrooms_outliers['terraceSurface'], orient='h')
#clened_data_without_bedrooms_outliers['terraceSurface'].agg(['count','skew','mean','median'])
# Out:
# count     4481.000000
# skew         2.127493
# mean         2.523990
# median       0.000000
# Name: terraceSurface, dtype: float64

# %% [markdown]
# **SAVING DATA TO NEW FILE**

# %%
# Save data to new csv file

clened_data_without_outliers.to_csv('clean_data.csv', index=False)
print("The CSV file was saved as 'clean_data_no_outliers.csv'.")

# Display first 5 rows
clened_data_without_outliers.head()
# Out:
# The CSV file was saved as 'clean_data_no_outliers.csv'.
#           id   locality_name Postal_code   Price Subtype  Number_of_bedrooms  \
# 0   20252354           Ronse        9600  319000   House                   3
# 1   20251003  Geraardsbergen        9500  299999   House                   3
# 8   20252002        Mechelen        2800  275000   House                   3
# 9   20252352           Gooik        1755  295000   House                   3
# 20  20250985        Oetingen        1755  560000   House                   4
#
#     Living_area            street number   latitude  longitude  Open_fire  \
# 0           125          Rotterij    148  50.744176   3.625722          0
# 1           167       Pirrestraat     17  50.752121   3.925495          0
# 8           154  Caputsteenstraat    150  51.033269   4.491795          0
# 9           172   Strijlandstraat     45  50.791877   4.084293          0
# 20          350   Blijkheerstraat     70  50.775412   4.047057          0
#
#     Swimming_Pool  hasTerrace  terraceSurface  gardenSurface   Kitchen_type  \
# 0               0           1               0            370           null
# 1               0           1               0            895      Installed
# 8               0           1              10             20  Semi equipped
# 9               0           1               0            300           null
# 20              0           1              40             32      Installed
#
#     Number_of_facades State_of_building  Furnished epc  price_per_sqm
# 0                   4       To renovate          0   F    2552.000000
# 1                   2              Good          0   D    1796.401198
# 8                   2       To renovate          0   E    1785.714286
# 9                   3       To renovate          0   F    1715.116279
# 20                  3              Good          0   C    1600.000000

# %%
clened_data_without_outliers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5828 entries, 0 to 9988
# Data columns (total 22 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  5828 non-null   int64
#  1   locality_name       5828 non-null   object
#  2   Postal_code         5828 non-null   object
#  3   Price               5828 non-null   Int64
#  4   Subtype             5828 non-null   object
#  5   Number_of_bedrooms  5828 non-null   Int64
#  6   Living_area         5828 non-null   Int64
#  7   street              5828 non-null   object
#  8   number              5807 non-null   object
#  9   latitude            5823 non-null   float64
#  10  longitude           5823 non-null   float64
#  11  Open_fire           5828 non-null   Int64
#  12  Swimming_Pool       5828 non-null   Int64
#  13  hasTerrace          5828 non-null   Int64
#  14  terraceSurface      5828 non-null   Int64
#  15  gardenSurface       5828 non-null   Int64
#  16  Kitchen_type        5828 non-null   object
#  17  Number_of_facades   5828 non-null   Int64
#  18  State_of_building   5828 non-null   object
#  19  Furnished           5828 non-null   Int64
#  20  epc                 5828 non-null   object
#  21  price_per_sqm       5828 non-null   float64
# dtypes: Int64(10), float64(3), int64(1), object(8)
# memory usage: 1.1+ MB
